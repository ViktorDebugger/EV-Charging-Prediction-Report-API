# %%
import pandas as pd
df = pd.read_csv('data/ev_charging_patterns.csv')

# %%
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df
# Out:
#         User ID  Vehicle Model  Battery Capacity (kWh) Charging Station ID Charging Station Location  Charging Start Time    Charging End Time  Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  Charging Cost (USD) Time of Day Day of Week  State of Charge (Start %)  State of Charge (End %)  Distance Driven (since last charge) (km)  Temperature (°C)  Vehicle Age (years)     Charger Type               User Type
# 0        User_1         BMW i3              108.463007         Station_391                   Houston  2024-01-01 00:00:00  2024-01-01 00:39:00              60.712346                   0.591363           36.389181            13.087717     Evening     Tuesday                  29.371576                86.119962                                293.602111         27.947953             2.000000  DC Fast Charger                Commuter
# ...

# %%
# !pip install openpyxl
df.to_excel('my_data.xlsx', index=False)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
unique_models = df['Vehicle Model'].unique()
print(list(unique_models))
# Out:
# ['BMW i3', 'Hyundai Kona', 'Chevy Bolt', 'Nissan Leaf', 'Tesla Model 3']

# %%
unique_locations = df['Ch`arging Station Location'].unique()
print(list(unique_locations))
# Out:
# ['Houston', 'San Francisco', 'Los Angeles', 'Chicago', 'New York']

# %%
unique_types = df['Charger Type'].unique()
print(list(unique_types))
# Out:
# ['DC Fast Charger', 'Level 1', 'Level 2']

# %%
unique_users = df['User Type'].unique()
print(list(unique_users))
# Out:
# ['Commuter', 'Casual Driver', 'Long-Distance Traveler']

# %%
rows

# %%
rows_with_empty = df[df.isnull().any(axis=1)]
rows_with_empty
# Out:
#         User ID  Vehicle Model  Battery Capacity (kWh) Charging Station ID Charging Station Location  Charging Start Time    Charging End Time  Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  Charging Cost (USD) Time of Day Day of Week  State of Charge (Start %)  State of Charge (End %)  Distance Driven (since last charge) (km)  Temperature (°C)  Vehicle Age (years)     Charger Type               User Type
# 21      User_22   Hyundai Kona               62.000000         Station_485                  New York  2024-01-01 21:00:00  2024-01-01 22:55:00              59.135032                   2.931761                 NaN            34.853234     Evening      Sunday                  71.530312                75.974352                                219.626357         -2.755069             5.000000          Level 1                Commuter
# ...

# %%
missing_counts = df.isnull().sum()
missing_counts[missing_counts > 0]
# Out:
# Energy Consumed (kWh)                       66
# Charging Rate (kW)                          66
# Distance Driven (since last charge) (km)    66
# dtype: int64

# %%
unique_counts = df.nunique()
unique_counts
# Out:
# User ID                                     1320
# Vehicle Model                                  5
# Battery Capacity (kWh)                       147
# Charging Station ID                          462
# Charging Station Location                      5
# Charging Start Time                         1320
# Charging End Time                           1309
# Energy Consumed (kWh)                       1254
# Charging Duration (hours)                   1320
# Charging Rate (kW)                          1254
# Charging Cost (USD)                         1320
# Time of Day                                    4
# Day of Week                                    7
# State of Charge (Start %)                   1320
# State of Charge (End %)                     1320
# Distance Driven (since last charge) (km)    1254
# Temperature (°C)                            1320
# Vehicle Age (years)                          114
# Charger Type                                   3
# ...

# %%
df.describe(include='all')
# Out:
#        User ID  Vehicle Model  Battery Capacity (kWh) Charging Station ID Charging Station Location  Charging Start Time    Charging End Time  Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  Charging Cost (USD) Time of Day Day of Week  State of Charge (Start %)  State of Charge (End %)  Distance Driven (since last charge) (km)  Temperature (°C)  Vehicle Age (years) Charger Type User Type
# count     1320           1320             1320.000000                1320                      1320                 1320                 1320            1254.000000                1320.000000         1254.000000          1320.000000        1320        1320                1320.000000              1320.000000                               1254.000000       1320.000000          1320.000000         1320      1320
# ...

# %%
rows, cols = df.shape

print(f"Кількість рядків: {rows}")
print(f"Кількість стовпців: {cols}")
# Out:
# Кількість рядків: 1320
# Кількість стовпців: 20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1320 entries, 0 to 1319
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   User ID                                   1320 non-null   object
#  1   Vehicle Model                             1320 non-null   object
#  2   Battery Capacity (kWh)                    1320 non-null   float64
#  3   Charging Station ID                       1320 non-null   object
#  4   Charging Station Location                 1320 non-null   object
#  5   Charging Start Time                       1320 non-null   object
#  6   Charging End Time                         1320 non-null   object
#  7   Energy Consumed (kWh)                     1254 non-null   float64
#  8   Charging Duration (hours)                 1320 non-null   float64
#  9   Charging Rate (kW)                        1254 non-null   float64
# ...

# %%
total_rows = df.shape[0]
print(f"Загальна кількість рядків: {total_rows}")

# Визначення рядків, де є хоча б одне NaN
rows_with_nan = df[df.isnull().any(axis=1)]

# Підрахунок кількості таких рядків
nan_rows_count = rows_with_nan.shape[0]
print(f"Кількість рядків з пропущеними значеннями: {nan_rows_count}")

# Обчислення співвідношення
ratio_of_nan_rows = nan_rows_count / total_rows

print(f"Співвідношення рядків з NaN до загальної кількості: {ratio_of_nan_rows:.2%}")
# Out:
# Загальна кількість рядків: 1320
# Кількість рядків з пропущеними значеннями: 189
# Співвідношення рядків з NaN до загальної кількості: 14.32%

# %%
ratio = (end_less_than_start_count / total_rows) * 100

print(f"Кількість випадків, коли кінцевий рівень заряду менший за початковий: {end_less_than_start_count}")
print(f"Співвідношення до загальної кількості рядків: {ratio:.2f}%")
# Out:
# Кількість випадків, коли кінцевий рівень заряду менший за початковий: 268
# Співвідношення до загальної кількості рядків: 20.30%

# %%
# Значення менші за 0 АБО більші за 100
invalid_values_mask = (df['State of Charge (Start %)'] < 0) | \
                      (df['State of Charge (Start %)'] > 100) | \
                      (df['State of Charge (End %)'] < 0) | \
                      (df['State of Charge (End %)'] > 100)

# Підрахунок кількості таких рядків
invalid_rows_count = invalid_values_mask.sum()

print(f"Кількість рядків з недійсними значеннями: {invalid_rows_count}")

# Обчислення співвідношення у відсотках
ratio = (invalid_rows_count / total_rows) * 100

print(f"Співвідношення рядків з недійсними значеннями до загальної кількості: {ratio:.2f}%")
# Out:
# Кількість рядків з недійсними значеннями: 32
# Співвідношення рядків з недійсними значеннями до загальної кількості: 2.42%

# %%
# 1. Перетворення 'Charging Start Time' на datetime
df['Charging Start Time'] = pd.to_datetime(df['Charging Start Time'])

# 2. Визначення функції для категоризації часу доби
def get_time_of_day(hour):
    if 6 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 18:
        return 'Afternoon'
    elif 18 <= hour < 22:
        return 'Evening'
    else:  # від 22:00 до 5:59
        return 'Night'

# 3. Застосування функції для створення нового стовпця
df['Calculated_Time_of_Day'] = df['Charging Start Time'].dt.hour.apply(get_time_of_day)

# 4. Підрахунок помилок
# Порівняння розрахованого та існуючого значень
errors = df[df['Time of Day'] != df['Calculated_Time_of_Day']]
number_of_errors = len(errors)

print(f"Кількість помилок у категоризації часу доби: {number_of_errors}")
# Out:
# Кількість помилок у категоризації часу доби: 1007

# %%
# Перетворення стовпців часу на datetime
df['Charging Start Time'] = pd.to_datetime(df['Charging Start Time'])
df['Charging End Time'] = pd.to_datetime(df['Charging End Time'])

# Загальна кількість рядків у датасеті
total_rows = df.shape[0]

# Варіант 1: Порівняння в годинах
calculated_duration_hours = (df['Charging End Time'] - df['Charging Start Time']).dt.total_seconds() / 3600
is_correct_hours = np.isclose(df['Charging Duration (hours)'].fillna(0), calculated_duration_hours.fillna(0), atol=0.001)
correct_rows_count_hours = is_correct_hours.sum()

ratio_hours = (correct_rows_count_hours / total_rows) * 100

print(f"Кількість рядків, де тривалість обчислена правильно (в годинах): {correct_rows_count_hours}")
print(f"Співвідношення до загальної кількості: {ratio_hours:.2f}%")

# Варіант 2: Порівняння в секундах
calculated_duration_sec = (df['Charging End Time'] - df['Charging Start Time']).dt.total_seconds()
is_correct_sec = np.isclose(df['Charging Duration (hours)'].fillna(0) * 3600, calculated_duration_sec.fillna(0), atol=0.1)
correct_rows_count_sec = is_correct_sec.sum()

ratio_sec = (correct_rows_count_sec / total_rows) * 100

print(f"\nКількість рядків, де тривалість обчислена правильно (в секундах): {correct_rows_count_sec}")
print(f"Співвідношення до загальної кількості: {ratio_sec:.2f}%")
# Out:
# Кількість рядків, де тривалість обчислена правильно (в годинах): 2
# Співвідношення до загальної кількості: 0.15%
#
# Кількість рядків, де тривалість обчислена правильно (в секундах): 0
# Співвідношення до загальної кількості: 0.00%

# %%
import pandas as pd
df = pd.read_csv('data/ev_charging_patterns.csv')
df['Charger Type'].value_counts()
# Out:
# Charger Type
# Level 1            459
# Level 2            431
# DC Fast Charger    430
# Name: count, dtype: int64

# %%
pd.crosstab(df['Charger Type'], df['Time of Day'])
# Out:
# Time of Day      Afternoon  Evening  Morning  Night
# Charger Type
# DC Fast Charger        102      123      111     94
# Level 1                100      131      112    116
# Level 2                108      108      113    102

# %%
df['Charging Station Location'].value_counts()
# Out:
# Charging Station Location
# Los Angeles      297
# San Francisco    264
# Houston          262
# New York         255
# Chicago          242
# Name: count, dtype: int64

# %%
df.groupby('Charger Type')['Battery Capacity (kWh)'].mean()
# Out:
# Charger Type
# DC Fast Charger    74.223005
# Level 1            74.876636
# Level 2            74.481497
# Name: Battery Capacity (kWh), dtype: float64

# %%
# !pip install seaborn
import seaborn as sns

sns.boxplot(x='Charger Type', y='Distance Driven (since last charge) (km)', data=df)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# <Axes: xlabel='Charger Type', ylabel='Distance Driven (since last charge) (km)'>

# %%
df.groupby('User Type')['Charging Rate (kW)'].mean()
# Out:
# User Type
# Casual Driver             25.642728
# Commuter                  26.934277
# Long-Distance Traveler    25.205906
# Name: Charging Rate (kW), dtype: float64
